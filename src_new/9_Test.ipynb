# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
path = '/mnt/24eb92b8-4fc1-4f32-b05c-deaa999ce6cf/Documents/datasets/face/imdb_crop/01/nm0000101_rm253151744_1952-7-1_2014.jpg'

# %%
img = Image.open(path)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500 at 0x7FDD74DC4B70>

# %%
img = img.resize((50, 50), Image.ANTIALIAS)
img = np.array(img)

# %%
plt.imshow(img)
