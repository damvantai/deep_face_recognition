# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("/home/neosai/Pictures/Screenshot from 2018-08-23 09-19-58.png")

# %%
plt.imshow(img)

# %%
for x_cor in range(0, 1280):
    y_cor = x_cor * 0.32 + 199
    cv2.circle(img, (int(x_cor), int(y_cor)), 5, (255, 255, 0), 2)

# %%
plt.imshow(img)
